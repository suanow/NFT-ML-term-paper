# %%
# parsing
import requests
import json
import webbrowser
import solana

# analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# modeling
import numpy as np
import sklearn

# just need it
import datetime
import time
import base64

# %%
def get_activity(collection: str, offset: int) -> json:
    """ Get the activity of the collection """
    url = 'http://api-mainnet.magiceden.dev/v2/collections/{symbol}/activities?offset={offset}&limit=100'.format(symbol=collection.lower().replace(" ", "_"), offset=offset)

    payload = {}
    headers = {}

    response = requests.get(url)
    data = json.loads(response.text)
    
    return data


def get_stats(collection: str, offset: int) -> json: 
    """ Get stats of the collection """
    url = 'http://api-mainnet.magiceden.dev/v2/collections/{symbol}/activities?offset={offset}&limit=1000'.format(symbol=collection.lower().replace(" ", "_"), offset=offset)

    payload = {}
    headers = {}

    response = requests.get(url)
    data = json.loads(response.text)
    
    return data


def get_sales(collection: str, offset: int) -> dict:
    """ Get only sales from the collection activity """
    json_obj = get_activity(collection=collection, offset=offset)

    if isinstance(json_obj, list) and all(isinstance(i, dict) for i in json_obj):
      new_obj = {}
      for obj in json_obj:
        if 'type' in obj and obj['type'] == 'buyNow':
          key = obj['collection'] + '-' + str(obj['slot'])
          new_obj[key] = {
            'type': obj['type'],
            'source': obj['source'],
            'collection': obj['collection'],
            'price': obj['price'],
            'image': obj['image']
          }

    else:
      new_obj = {}

    return new_obj


def get_bids(collection: str, offset: int) -> dict:
    """ Get only bids from the collection activity """
    json_obj = get_activity(collection=collection, offset=offset)

    if isinstance(json_obj, list) and all(isinstance(i, dict) for i in json_obj):
      new_obj = {}
      for obj in json_obj:
        if 'type' in obj and obj['type'] == 'bid':
          key = obj['collection'] + '-' + str(obj['slot'])
          new_obj[key] = {
            'type': obj['type'],
            'source': obj['source'],
            'collection': obj['collection'],
            'price': obj['price']
          }

    else:
      new_obj = {}

    return new_obj


def get_listings(collection: str, offset: int) -> json:
    """ Get listings of the collection """
    url = 'http://api-mainnet.magiceden.dev/v2/collections/{symbol}/listings?offset={offset}&limit=20'.format(symbol=collection.lower().replace(" ", "_"), offset=offset)

    payload = {}
    headers = {}

    response = requests.get(url)
    data = json.loads(response.text)
    
    return data

# %%
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:384, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         except Exception as e:
#     382             # Remove the TypeError from the exception chain in Python 3;
#     383             # otherwise it looks like a programming error was the cause.
# --> 384             six.raise_from(e, None)
#     385 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:2, in raise_from(value, from_value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:380, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379 try:
# --> 380     httplib_response = conn.getresponse()
#     381 except Exception as e:
#     382     # Remove the TypeError from the exception chain in Python 3;
#     383     # otherwise it looks like a programming error was the cause.
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1371, in HTTPConnection.getresponse(self)
#    1370 try:
# -> 1371     response.begin()
#    1372 except ConnectionError:
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:319, in HTTPResponse.begin(self)
#     318 while True:
# --> 319     version, status, reason = self._read_status()
#     320     if status != CONTINUE:
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:280, in HTTPResponse._read_status(self)
#     279 def _read_status(self):
# --> 280     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281     if len(line) > _MAXLINE:
#
# File ~/opt/anaconda3/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:637, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     635     e = ProtocolError('Connection aborted.', e)
# --> 637 retries = retries.increment(method, url, error=e, _pool=self,
#     638                             _stacktrace=sys.exc_info()[2])
#     639 retries.sleep()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py:368, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     367 if read is False or not self._is_method_retryable(method):
# --> 368     raise six.reraise(type(error), error, _stacktrace)
#     369 elif read is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py:686, in reraise(tp, value, tb)
#     685     raise value.with_traceback(tb)
# --> 686 raise value
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:597, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     596 # Make the request on the httplib connection object.
# --> 597 httplib_response = self._make_request(conn, method, url,
#     598                                       timeout=timeout_obj,
#     599                                       body=body, headers=headers,
#     600                                       chunked=chunked)
#     602 # If we're going to release the connection in ``finally:``, then
#     603 # the response doesn't need to know about the connection. Otherwise
#     604 # it will also try to release it and we'll have a double-release
#     605 # mess.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 386     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     387     raise
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:317, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     316 if 'timed out' in str(err) or 'did not complete (read)' in str(err):  # Python < 2.7.4
# --> 317     raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
#
# ReadTimeoutError: HTTPSConnectionPool(host='api-mainnet.magiceden.dev', port=443): Read timed out. (read timeout=None)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# /Users/suanow/Desktop/NFT ML/models/sandbox.ipynb Ячейка 3 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/suanow/Desktop/NFT%20ML/models/sandbox.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> while True:
#       <a href='vscode-notebook-cell:/Users/suanow/Desktop/NFT%20ML/models/sandbox.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>     offset = 0
# ----> <a href='vscode-notebook-cell:/Users/suanow/Desktop/NFT%20ML/models/sandbox.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a>     all_activity.append(get_activity('y00ts', offset))
#       <a href='vscode-notebook-cell:/Users/suanow/Desktop/NFT%20ML/models/sandbox.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>     offset += 1
#       <a href='vscode-notebook-cell:/Users/suanow/Desktop/NFT%20ML/models/sandbox.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> print(len(all_activity))
#
# /Users/suanow/Desktop/NFT ML/models/sandbox.ipynb Ячейка 3 in get_activity(collection, offset)
#       <a href='vscode-notebook-cell:/Users/suanow/Desktop/NFT%20ML/models/sandbox.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> payload = {}
#       <a href='vscode-notebook-cell:/Users/suanow/Desktop/NFT%20ML/models/sandbox.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> headers = {}
# ----> <a href='vscode-notebook-cell:/Users/suanow/Desktop/NFT%20ML/models/sandbox.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> response = requests.get(url)
#       <a href='vscode-notebook-cell:/Users/suanow/Desktop/NFT%20ML/models/sandbox.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> data = json.loads(response.text)
#      <a href='vscode-notebook-cell:/Users/suanow/Desktop/NFT%20ML/models/sandbox.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> return data
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:723, in Session.send(self, request, **kwargs)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:723, in <listcomp>(.0)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:578, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#

#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 'G55Wd5vEwKq5zfPeyBfk442C4Ctfcc9dQaifqioFcG41',
#   'sellerReferral': '',
#   'price': 220,
#   'image': 'https://metadata.y00ts.com/y/9453.png'},
#  {'signature': '2AE26p4T3W3Ka3F7yRx1VrHRNxxirayk35JFPPpBNqgwZVRMbKKJZNGyKY51rQQxMiqwhAfQB5gTaKy9Dta5JZ6e',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': '4HmysTzRzJrEBCKryERxhDhZxwX7d7Y8oP8XPeL294ge',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168923195,
#   'blockTime': 1671962494,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 'F4eGnr6BqBuHLqxmPxckgKNpZotKKQinZAMS9G2xoPcF',
#   'sellerReferral': '',
#   'price': 157.62,
#   'image': 'https://metadata.y00ts.com/y/5859.png'},
#  {'signature': '3v6dLZNByaKP6WRCXAsFrhLgicTJDJrnzmRrxPQkcgbJYmU3kExrRHewycYuenKqTV9sqQZVVwiYrAPR5oopmUYY',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'G3xLCz3bq5Uvwt3f4b2LNGJSEdP4Jovm4tnPdGLS48w8',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168922802,
#   'blockTime': 1671962321,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 'Hjj9YoRKg3Q8fuRwiqhFs4K1xvyj2QSB7NyHdz1J6kDP',
#   'sellerReferral': '',
#   'price': 157.6299,
#   'image': 'https://metadata.y00ts.com/y/10647.png'},
#  {'signature': '2js7jGvTSJ4bs5kBLF3cVXn6TuVP18L7dBhVWbXD5ABFmv5h11KfV7mhpUmp9wdmz82EJKdi5UvwysTtd73YcQp2',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'J96xMxSmbdoJazqUn4tE3zNbWFkyWFXCNEy8ch5QaPJG',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168922388,
#   'blockTime': 1671962127,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': '4acUMgKaoiTbWbfWtRa5AW2jX4zCzpVAK2zswcDF5sn2',
#   'sellerReferral': '',
#   'price': 170,
#   'image': 'https://metadata.y00ts.com/y/660.png'},
#  {'signature': '1aczneujZqC7Zs8jvet7t4fUFXm1Sk3FPbDcwJEMeprkkRPBrLmcH4P2FyxN2e1m9bGz84kX5TrsKdbsUSDvcfY',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'ua9kCGbXxZdcoN3Gqd4PH33Fy4RBAVEqg4B2jhY2s7N',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168921507,
#   'blockTime': 1671961742,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 'HPz45FL6w2n28XKf8A8rekBjMiM8RyhvuEaUugJhZ6m6',
#   'sellerReferral': '',
#   'price': 174.99,
#   'image': 'https://metadata.y00ts.com/y/8608.png'},
#  {'signature': 'FGLPwPsCgF5kmznUgP5WbxHUweVXdcgEdKULvyRSExFjm1GF9C7ikKFbGBqBh2Ni69i9AbvqpxFKKQEfVnrC9cP',
#   'type': 'bid',
#   'source': 'mmm',
#   'tokenMint': None,
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168920580,
#   'blockTime': 1671961318,
#   'buyerReferral': '',
#   'sellerReferral': '',
#   'price': 155.901},
#  {'signature': '2chvScZ81FsbsoMrCLsBqY8AWyVcHpBa5bnHYUd1jSqhwUrarivkgHAQoKTXk5rjJNoNNWQqo1gGe4HFRs4nwkQb',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'Bo297KChQAfuZ9TVivm4aziqz2KiK4jAfVeNDZAYAChZ',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168920532,
#   'blockTime': 1671961296,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 'GjDCjnfonYTL395ZKdz2yxg5zHojUs92HbGEhcvDbzTi',
#   'sellerReferral': '',
#   'price': 222,
#   'image': 'https://metadata.y00ts.com/y/12357.png'},
#  {'signature': 'dkNxWQcgTvew4m1Lwb1dFzSYSLP9KbVTuK1XKyopWCWcTmw1Y5dhaNNrEJeZq7LQaKvdENdRBXFAkko1cAEJxa2',
#   'type': 'buyNow',
#   'source': 'magiceden_v2',
#   'tokenMint': 'C4UYc5rcWRKJJ6KJRimbQ9pw2WmUSHZJ1BiWQb6asjor',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 

#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'H4xVffbjtxToqD9WzPRxFT8UZJvYrKKo6Y552xSVoPT6',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168918852,
#   'blockTime': 1671960526,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 'BBpCqcESVU5xJToXFQsjD1ZHqeH1hcnpwC8xiw4xPYBU',
#   'sellerReferral': '',
#   'price': 235,
#   'image': 'https://metadata.y00ts.com/y/3522.png'},
#  {'signature': '4HCq5CUufAsdbLs34KUSusjHtfbyni9aAZ6zHmwuqinVMqT5ymhS9jANuHzb1LQNdkNZXz3ugAiZMXXbDrr9HisP',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'J96xMxSmbdoJazqUn4tE3zNbWFkyWFXCNEy8ch5QaPJG',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168918228,
#   'blockTime': 1671960242,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': '4acUMgKaoiTbWbfWtRa5AW2jX4zCzpVAK2zswcDF5sn2',
#   'sellerReferral': '',
#   'price': 175,
#   'image': 'https://metadata.y00ts.com/y/660.png'},
#  {'signature': '2YMjuVdJYUJEuoQvSwZuUCRvSaAdu4nTadJ51xsUi54xuazqh54b7kGyHYsZBVWXGwV2WX2DcQHzM1MumsnUgx9F',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'CwEv392cq55cQ8pVBrJGzPEMoc3JWtf2wgtuyzEngNEj',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168917619,
#   'blockTime': 1671959970,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 'BzVYLXyoFjwvAb3J53Hbxv2uLp6axDY7wi7cW42524ex',
#   'sellerReferral': '',
#   'price': 180,
#   'image': 'https://metadata.y00ts.com/y/4429.png'},
#  {'signature': '5Kh6K4jjEzHvGadr3CJJgSABVGNMZUnDznwQfHLboqKYMyBCatyZgwmRkLeSNcQd4roK8aiLryeFsksFvXxopo9j',
#   'type': 'delist',
#   'source': 'magiceden_v2',
#   'tokenMint': 'CwEv392cq55cQ8pVBrJGzPEMoc3JWtf2wgtuyzEngNEj',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168917570,
#   'blockTime': 1671959948,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 'BzVYLXyoFjwvAb3J53Hbxv2uLp6axDY7wi7cW42524ex',
#   'sellerReferral': '',
#   'price': 0,
#   'image': 'https://metadata.y00ts.com/y/4429.png'},
#  {'signature': '5LVTvq69pgz43NTjadCWkNxJ7aKJaYRXi44cHgEi9GpKrAPQ63Ag9numTJKp7Pd43kcX3igSMr57jTwg4mNvxKTG',
#   'type': 'buyNow',
#   'source': 'magiceden_v2',
#   'tokenMint': 'BdbHKsDHJxXRNf9JBpxfhxCoJhuVdDxX5zstsmdziRo5',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168917444,
#   'blockTime': 1671959892,
#   'buyer': '8esCLNNxXvuxPThD6UP3khG2svBiuxdccAynLzHBouwZ',
#   'buyerReferral': '',
#   'seller': 'F25C7c7XujAVZikk11ApBNrAWP3AMRtHzUAAY1MBFu79',
#   'sellerReferral': '',
#   'price': 157.7,
#   'image': 'https://metadata.y00ts.com/y/13585.png'},
#  {'signature': 'i6vJufRyhW8c8i8V3KjkVzedvymCd1LDn3HNDGbiXxBMSSunc9rQBrLkzTXqeaHbKwEDu85FV5UKG7hJRCy4Mke',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': '7wp4qby7uyxbGrK4hgT91FmpFtrVgCVLdD5G1ZGjYoyo',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168917196,
#   'blockTime': 1671959783,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 

#   'type': 'cancelBid',
#   'source': 'mmm',
#   'tokenMint': None,
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168916046,
#   'blockTime': 1671959277,
#   'buyerReferral': '',
#   'sellerReferral': '',
#   'price': 0},
#  {'signature': '2GyBkXdhavn1UfofQXK867dcVwQCa3xxtW5wKmXaZp7MWNYqfBBpgHrdhBc1xevmi2me6V4V2Ewu867w85bD5GN8',
#   'type': 'bid',
#   'source': 'mmm',
#   'tokenMint': None,
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168915971,
#   'blockTime': 1671959243,
#   'buyerReferral': '',
#   'sellerReferral': '',
#   'price': 155.904},
#  {'signature': '3bjvSM9Wfyry5tKXm3EajkhGbhicu5WmtJLbaPLb5gHkdmdwURtBV8Heaxy43FLvWNsTqBYfuRBS9qTpQuEmY8bc',
#   'type': 'bid',
#   'source': 'mmm',
#   'tokenMint': None,
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168915913,
#   'blockTime': 1671959218,
#   'buyerReferral': '',
#   'sellerReferral': '',
#   'price': 155.903},
#  {'signature': 'aWWw8WheFHpZP42pdQGA8jrSiLqd7hqsAz7wiuuybUwXdC8n7vXL3roZDVCwdtzFEx6j96tpwvvgZaUp12vMXrc',
#   'type': 'cancelBid',
#   'source': 'mmm',
#   'tokenMint': None,
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168915636,
#   'blockTime': 1671959098,
#   'buyerReferral': '',
#   'sellerReferral': '',
#   'price': 0},
#  {'signature': '6Mpv3rWASxJxJeRdGZwcURLfopBsPYynRhGB3izmDMnYAD89BtLkUdxbdKttWTsoPqQhQ4u9FgP3S8g2FZCNuSW',
#   'type': 'bid',
#   'source': 'mmm',
#   'tokenMint': None,
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168915369,
#   'blockTime': 1671958978,
#   'buyerReferral': '',
#   'sellerReferral': '',
#   'price': 155.902},
#  {'signature': '5rj89rWQsRULPT5EJbxWRom16cpeVBoqVKgajG2zihuxRCZFx8C7tJ68H3i8PyizxM2JpBa2Pz5W8YxaK5KHnYG6',
#   'type': 'cancelBid',
#   'source': 'mmm',
#   'tokenMint': None,
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168915335,
#   'blockTime': 1671958962,
#   'buyerReferral': '',
#   'sellerReferral': '',
#   'price': 0},
#  {'signature': '2xr3MEx6yceUc7zjTyo74jGoGQjiDL2zsjgMQDtP3SAAbX1bcsqwgAt3E7pthFx5oitKtrrwYtkbouBVzAkvcGea',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'H1s8zav9xWfX4sV1krXYP2s6P5HtzMjngQoSdR1mrkoU',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168914073,
#   'blockTime': 1671958399,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 'DuQNqgRMqVdwRf7V1zHjEsuSrsqjHhiqKDXWiS46GATd',
#   'sellerReferral': '',
#   'price': 168.5,
#   'image': 'https://metadata.y00ts.com/y/7498.png'},
#  {'signature': '2JQpUPx4xLNqbzohyvEp7q2pEKDCLCyJprgZeCyvneM3NYa4qxMreuYZ3B8j8GzG2mRoj67Pwk4ap3bD2qtYGA61',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'B18jjyStc1taKoefSoGjd1KSEzi3Cu45GT1dGc65dFuJ',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168914038,
#   'blockTime': 1671958384,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 'DuQNqgRMqVdwRf7V1zHjEsuSrsqjHhiqKDXWiS46GATd',
#   'sellerReferral': '',
#   'price': 167,
#   'image': 'https://metadata.y00ts.com/y/9771.png'},
#  {'signature': '5ndivhmvQcbz861oiySsnvjcxykSWs8qT6UaejfPrgST35eMTSTUgfPpM4RTNYF8DgPztDWg5NbUoDUCqfoJAa3u',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'J96xMxSmbdoJazqUn4tE3zNbWFkyWFXCNEy8ch5QaPJG',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168913501,
#   'blockTime': 1671958140,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': '4acUMgKaoiTbWbfWtRa5AW2jX4zCzpVAK2zswcDF5sn2',
#   'sellerReferral': '',
#   'price': 175,
#   'image': 'https://metadata.y00ts.com/y/660.png'},
#  {'signature': '3cDtrMYrmVVfH4cuMejRjAkioCd5grX7aLrjgGtt724xWUPCWhNnhSyHz9EEPxEehneeAh35nuKGx1kfnftzFkdu',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'J96xMxSmbdoJazqUn4tE3zNbWFkyWFXCNEy8ch5QaPJG',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168912661,
#   'blockTime': 1671957766,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': '4acUMgKaoiTbWbfWtRa5AW2jX4zCzpVAK2zswcDF5sn2',
#   'sellerReferral': '',
#   'price': 180,
#   'image': 'https://metadata.y00ts.com/y/660.png'},
#  {'signature': '5R37CfVaFp1pmnNpkT4hyyETFDv4fUxsZN4AvoyL9TBGBigJUhxmbSaBK2xKW7pdkrJ9Fs1cmzyK7hjXDdtUfJ1i',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': '9fr2hVFDC9pPEHH7H9xxQ38wH7PWhCkqMV6uhxKxXYB5',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168911909,
#   'blockTime': 1671957341,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': '5SkhphG62nMnSrpGoB2P5fhkMVYRqutaxyy8z67ZbVj2',
#   'sellerReferral': '',
#   'price': 159.95,
#   'image': 'https://metadata.y00ts.com/y/8684.png'},
#  {'signature': '5qtxWnw4ZWKNCzLV2EewoyxqoXvaCe4GVQwZTqhJTvhTHfwKcqXXyLCMruJ3m5fbvVrpCNPqUaGRrqFPK5r1gTxn',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': '4AxFj7C9tWvbFTgJ8WLvRsg3A5uXyXD2m4ZzWZkaHhDD',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168911666,
#   'blockTime': 1671957226,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': '2VenqvWgSeENRe3aGJ5HjpMzqBM79vDvst5eh9b51QjA',
#   'sellerReferral': '',
#   'price': 333,
#   'image': 'https://metadata.y00ts.com/y/12855.png'},
#  {'signature': '2ERCkbhz8sFUKa6Bo9t2TJxWzAoFJAneJb57mcGzSo9Sa7TzgrEhQXCVS7oXER8MFHr5r3L4Qu1EMBsTP2sQU8J8',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': '99oQvdQaxZF4ENPs7gcewybkosvWmPPo4bhNLyZJ3qA5',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168911600,
#   'blockTime': 1671957197,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': '2VenqvWgSeENRe3aGJ5HjpMzqBM79vDvst5eh9b51QjA',
#   'sellerReferral': '',
#   'price': 249,
#   'image': 'https://metadata.y00ts.com/y/12669.png'},
#  {'signature': '5eVJbVwLV6kg5VMzFPa7o3bLdxkGBcHs51SsEQXC3cTEiamyFgQgfDDCDi8PAoiHbHs9R6WVG7LoGFKt1hmEW4u1',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': 'CXjxceuyS7RAETvf792dTmhTXp8cwrfFMYG4wSPZmQNx',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168911464,
#   'blockTime': 1671957131,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': '2VenqvWgSeENRe3aGJ5HjpMzqBM79vDvst5eh9b51QjA',
#   'sellerReferral': '',
#   'price': 249,
#   'image': 'https://metadata.y00ts.com/y/2014.png'},
#  {'signature': '5nQBLfpK5ioBQudQg31GmMTenLVbAUSy1ZLXew2FUwfbvD1PHfLmwYRu5nYHD9sLtaLBXae2yv9CYBudJ53idZW3',
#   'type': 'list',
#   'source': 'magiceden_v2',
#   'tokenMint': '8HTQ6dQNWf23eQ6sDVhShCfpjnYyBXND64vuzW6UsKz4',
#   'collection': 'y00ts',
#   'collectionSymbol': 'y00ts',
#   'slot': 168910202,
#   'blockTime': 1671956566,
#   'buyer': None,
#   'buyerReferral': '',
#   'seller': 'F8a9E37ugZevgQG6aZRh5mHjkzZQ61zKXM8SqKrMUVLB',
#   'sellerReferral': '',
#   'price': 165,
#   'image': 'https://metadata.y00ts.com/y/12387.png'}]
